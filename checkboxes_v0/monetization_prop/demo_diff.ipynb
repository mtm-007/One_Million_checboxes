# %%
import replicate
import requests
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
REPLICATE_API_TOKEN = os.getenv("REPLICATE_API_TOKEN")

# %%
#replicate = Client(api_token=REPLICATE_API_TOKEN)
from urllib3 import response


output = replicate.run(
    "mtm-007/custm_diffusion:4536d1407dddcdc365ecaee695283e2b1d3307bb214550c8e35d245abada3994",
    input = {"prompt": "A cat tackle Ronaldo in green field"
    }
)

# To access the file URL:
print(output)

response = requests.get(output)
response.raise_for_status()

with open("output.png", "wb") as f:
    f.write(response.content)
print("saved as output.png")
# Out:
# https://replicate.delivery/czjl/INcXOmt4G45iK1WqfLSi2gwj3A210Kp0ECUXZOjelhvonCzVA/0.25928109884262085__A_%20_c_a_t_%20_t_a_c_k_l_e_%20_R_o_n_a_l_d_o_%20_i_n_%20_g_r_e_e_n_%20_f_i_e_l_d_.png
